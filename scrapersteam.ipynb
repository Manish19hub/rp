# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.14.2)
# Requirement already satisfied: pandas in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\manis\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

url = "https://store.steampowered.com/appreviews/730?json=1"

response = requests.get(url)

data = response.json()

reviews_data = data['reviews']

customers = []
reviews = []
ratings = []
tags = []

for review in reviews_data:

    customer = review['author']['steamid']

    comment = review['review']

    rating = "Positive" if review['voted_up'] else "Negative"

    tag = review['language']

    customers.append(customer)
    reviews.append(comment)
    ratings.append(rating)
    tags.append(tag)

df = pd.DataFrame({
    'Customer Name': customers,
    'Review': reviews,
    'Rating': ratings,
    'Tag': tags
})

print(df)

df.to_csv("steam_reviews.csv", index=False)

print("Scraping Completed")
# Out:
#         Customer Name                                             Review  \
# 0   76561199141679921  Very goood game if you are from Russia or you ...
# 1   76561199884102578  Counter-Strike 2 - this isn’t a shooter, it’s ...
# 2   76561198878876128  Hackers hackers hackers everygame, valve doesn...
# 3   76561199577366977  very interesting game I broke two mice and hea...
# 4   76561199850965103  You play well = cheater\nYou play bad = noob\n...
# 5   76561199127701778  After 580 hours, I can confidently say my ment...
# 6   76561198141430579  Get yourself a friend, play wingman, go do abs...
# 7   76561197981915477  Counter-Strike 2 is a fantastic game if you en...
# 8   76561199813772035  Counter-Strike 2 feels like Valve took a legen...
# 9   76561199492902908  Great Game.\nGreat Graphic.\nSo many Toxic Pla...
# 10  76561198963608852  Be respectful of others and avoid conflicts. P...
# 11  76561198715882977  Absolutely unplayable. CS2 is a massive downgr...
# 12  76561199200690842  I love this game its worth ur time. Its maybe ...
# 13  76561198979046439  If you hate yourself and having any sort of fu...
# 14  76561199236678728  ragebaiting game\nmeet cheater\ngood cheater\n...
# 15  76561199786360330  bullllllllllshet game............... the bulls...
# 16  76561199561600477  One of the best game before now its just piece...
# 17  76561198790397030  Bom jogo, o problema são os xitters.Bom jogo, ...
# 18  76561198815564182  the inability to tab out of this game without ...
# 19  76561198165620297  Listen up, you pixel-pushing amateurs.\n\nI’ve...
#
#       Rating      Tag
# 0   Positive  english
# 1   Positive  english
# 2   Negative  english
# 3   Positive  english
# 4   Negative  english
# 5   Negative  english
# 6   Positive  english
# 7   Positive  english
# 8   Negative  english
# 9   Positive  english
# 10  Positive  english
# 11  Negative  english
# 12  Positive  english
# 13  Negative  english
# 14  Positive  english
# 15  Negative  english
# 16  Negative  english
# 17  Positive  english
# 18  Negative  english
# 19  Positive  english
# Scraping Completed
