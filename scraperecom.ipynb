# %%
# pip install requests beautifulsoup4 pandas

import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops"

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

products = soup.find_all('div', class_='thumbnail')

names = []
ratings = []
reviews = []
tags = []
customers = []

for product in products:

    # Product Name
    name = product.find('a', class_='title').text.strip()

    # Rating
    rating = len(product.find_all('span', class_='glyphicon glyphicon-star'))

    # Review Count
    review_tag = product.find('p', class_='review-count')

    if review_tag:
        review = review_tag.text.strip()
    else:
        review = "No Reviews"

    # Tag
    tag = "Laptop"

    # Customer Name
    customer = "Anonymous"

    names.append(name)
    ratings.append(rating)
    reviews.append(review)
    tags.append(tag)
    customers.append(customer)

# Create DataFrame
df = pd.DataFrame({
    'Product Name': names,
    'Rating': ratings,
    'Reviews': reviews,
    'Tag': tags,
    'Customer Name': customers
})

print(df)
print("Scraping Completed")
# Out:
#      Product Name  Rating     Reviews     Tag Customer Name
# 0  Packard 255 G2       0   2 reviews  Laptop     Anonymous
# 1   Aspire E1-510       0   2 reviews  Laptop     Anonymous
# 2  ThinkPad T540p       0   2 reviews  Laptop     Anonymous
# 3         ProBook       0   8 reviews  Laptop     Anonymous
# 4   ThinkPad X240       0  12 reviews  Laptop     Anonymous
# 5  Aspire E1-572G       0   2 reviews  Laptop     Anonymous
# Scraping Completed
