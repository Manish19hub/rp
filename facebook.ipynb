# %%
import pandas as pd

# %%
df= pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
photo_posts=df[df['Type']== 'Photo']

# %%
status_posts= df[df['Type']=='Status']

# %%
video_posts = df[df['Type'] == 'Video']
link_posts = df[df['Type'] == 'Link']

# %%
merged_data= pd.concat([status_posts,photo_posts])

# %%
merged_data.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sorted_data = df.sort_values(by='Page total likes', ascending=False)

sorted_data.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 13            139441   Photo         2          12             5          3
# 1             139441  Status         2          12             3         10
# 0             139441   Photo         2          12             4          3
# 5             139441  Status         2          12             1          9
# 4             139441   Photo         2          12             2          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 13   0.0                       2549                             4896
# 1    0.0                      10460                            19057
# 0    0.0                       2752                             5091
# 5    0.0                      10472                            20849
# 4    0.0                       7244                            13594
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
transpose_data=df.transpose()

# %%
transpose_data.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %%
melted_data = pd.melt(df,id_vars=['Type'],value_vars=['like', 'share', 'comment'],var_name='Metric',value_name='Value')

melted_data.head()
# Out:
#      Type Metric   Value
# 0   Photo   like    79.0
# 1  Status   like   130.0
# 2   Photo   like    66.0
# 3   Photo   like  1572.0
# 4   Photo   like   325.0

# %%
pivot_data = melted_data.pivot_table(index='Type',columns='Metric',values='Value',aggfunc='mean')

pivot_data
# Out:
# Metric    comment        like      share
# Type
# Link     2.818182   73.318182  12.909091
# Photo    7.492958  182.611765  27.158768
# Status   8.911111  176.711111  31.422222
# Video   12.285714  231.428571  52.142857
