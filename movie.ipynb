# %%
import pandas as pd

# %%
df=pd.read_csv("movies_metadata.csv",sep=",",low_memory=False)

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
eng_movie=df[df['original_language']=='en']
fr_movie=df[df['original_language']=='fr']
it_movie=df[df['original_language']=='it']
zh_movie=df[df['original_language']=='zh']

# %%
merged_data= pd.concat([eng_movie,it_movie])

# %%
df2= pd.read_csv('ratings_small.csv',sep=',')
sorted_data = df2.sort_values(by='rating',ascending=False)
sorted_data.tail()
# Out:
#        userId  movieId  rating   timestamp
# 17184     111     3160     0.5  1097429253
# 24124     174     1252     0.5  1109621175
# 49399     359     4069     0.5  1339227065
# 24287     176     1232     0.5  1340715213
# 17225     111     3994     0.5  1097431467

# %%
melted_data= pd.melt(df, id_vars=['original_language'], value_vars=['original_title','overview','popularity','release_date'], var_name='metric', value_name='Value')
print(melted_data.head())
# Out:
#   original_language          metric                        Value
# 0                en  original_title                    Toy Story
# 1                en  original_title                      Jumanji
# 2                en  original_title             Grumpier Old Men
# 3                en  original_title            Waiting to Exhale
# 4                en  original_title  Father of the Bride Part II

# %%
print(df.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='str')

# %%
melted_data = pd.melt(
    df,
    id_vars=['original_language'],
    value_vars=['budget', 'revenue', 'popularity', 'vote_average'],
    var_name='metric',
    value_name='Value'
)

print(melted_data.head())
# Out:
#   original_language  metric     Value
# 0                en  budget  30000000
# 1                en  budget  65000000
# 2                en  budget         0
# 3                en  budget  16000000
# 4                en  budget         0

# %%
transpose_data= df.transpose()
transpose_data.head()
# Out:
#                                                                    0      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
#
#                                                                    1      \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                             NaN
#
#                                                                    2      \
# ...

# %%
pivot_data = melted_data.pivot_table(index='original_language',columns='metric',values='Value',aggfunc='count')
pivot_data
# Out:
# metric             budget  popularity  revenue  vote_average
# original_language
# 104.0                   1           0        0             0
# 68.0                    1           0        0             0
# 82.0                    1           1        0             0
# ab                     10          10       10            10
# af                      2           2        2             2
# ...                   ...         ...      ...           ...
# vi                     10          10       10            10
# wo                      5           5        5             5
# xx                     33          33       33            33
# zh                    409         409      409           409
# zu                      1           1        1             1
#
# [92 rows x 4 columns]
